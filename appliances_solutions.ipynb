# %% [markdown]
# import library

# %%
import pandas as pd

# %% [markdown]
# Load the dataset

# %%
data = pd.read_csv('./datasets/Sales_Profit_Data_Electrical_Appliances.csv')

# %% [markdown]
#  Display the first 5 rows of the dataset

# %%
data.head()
# Out:
#    Order ID Order Date  Unit Cost   Price  Order Qty  Cost of Sales     Sales  \
# 0         1     6/3/16  10.297929  198.00          8      82.383431  1544.400
# 1        10    9/10/18  95.053423   99.00         18    1710.961615  1702.800
# 2       100     4/7/17   0.337961  129.00         13       4.393492  1599.600
# 3      1000     2/8/17  31.489398   99.00          4     125.957591   396.000
# 4     10000     3/4/19  20.634788   22.99          8     165.078305   170.126
#
#         Profit   Channel                     Promotion Name  \
# 0  1462.016569     Store         European Holiday Promotion
# 1    -8.161615  Reseller             Asian Spring Promotion
# 2  1595.206508     Store    North America Holiday Promotion
# 3   270.042409     Store  European Back-to-Scholl Promotion
# 4     5.047695    Online         European Holiday Promotion
#
#                                         Product Name          Manufacturer  \
# 0     A. Datum Point Shoot Digital Camera M500 Black  A. Datum Corporation
# 1                   Adventure Works LCD17 E200 Black       Adventure Works
# 2  Proseware Ink Jet Wireless All-In-One Printer ...       Proseware, Inc.
# 3                               WWI LCD17 E200 Black  Wide World Importers
# 4                 Contoso Multi-line phones M30 Grey          Contoso, Ltd
#
#        Product Sub Category         Product Category         Region  \
# 0           Digital Cameras  Cameras and camcorders          Europe
# 1                  Monitors                Computers           Asia
# 2  Printers, Scanners & Fax                Computers  North America
# 3                  Monitors                Computers         Europe
# 4      Home & Office Phones              Cell phones         Europe
#
#                   City         Country
# 0              Baildon  United Kingdom
# 1              Beijing           China
# 2  Queen Anne's County   United States
# 3               Torino           Italy
# 4               Berlin         Germany

# %% [markdown]
# Display the last 5 rows of the dataset

# %%
data.tail()
# Out:
#        Order ID Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 14995      9991    10/7/16   13.416234    13.5          5      67.081169
# 14996      9993    2/23/19  173.672641   699.0          9    1563.053767
# 14997      9995    9/13/17  339.125266   411.0         12    4069.503190
# 14998      9997    1/31/18   72.059072   188.0         12     864.708865
# 14999      9999    9/22/18  782.885394  1560.0          9    7045.968542
#
#          Sales       Profit  Channel                          Promotion Name  \
# 14995     67.5     0.418831  Catalog                             No Discount
# 14996   6221.1  4658.046233    Store       European Back-to-Scholl Promotion
# 14997   4932.0   862.496810   Online               European Spring Promotion
# 14998   2237.2  1372.491135    Store  North America Back-to-School Promotion
# 14999  12792.0  5746.031458    Store                  Asian Spring Promotion
#
#                                             Product Name  \
# 14995        Contoso Education Supplies Bundle E200 Grey
# 14996                           WWI Laptop15 M0150 Black
# 14997  Fabrikam Budget Movie-Maker 1/3'' 8.5mm E200 B...
# 14998       A. Datum All in One Digital Camera M200 Pink
# 14999  Fabrikam Independent filmmaker 1/3'' 8.5mm X20...
#
#                Manufacturer   Product Sub Category         Product Category  \
# 14995          Contoso, Ltd  Computers Accessories                Computers
# 14996  Wide World Importers                Laptops                Computers
# 14997        Fabrikam, Inc.             Camcorders  Cameras and camcorders
# 14998  A. Datum Corporation        Digital Cameras  Cameras and camcorders
# 14999        Fabrikam, Inc.             Camcorders  Cameras and camcorders
#
#               Region           City        Country
# 14995  North America  North Harford  United States
# 14996         Europe          Berne    Switzerland
# 14997         Europe         Berlin        Germany
# 14998  North America         Oregon  United States
# 14999           Asia      Hong Kong          China

# %% [markdown]
# Get the number of rows and columns

# %%
data.shape
# Out:
# (15000, 17)

# %% [markdown]
# Get the column names

# %% [markdown]
#  Get the data types of each column

# %%
data.dtypes
# Out:
# Order ID                  int64
# Order Date               object
# Unit Cost               float64
# Price                   float64
# Order Qty                 int64
# Cost of Sales           float64
# Sales                   float64
# Profit                  float64
# Channel                  object
# Promotion Name           object
# Product Name             object
# Manufacturer             object
# Product Sub Category     object
# Product Category         object
# Region                   object
# City                     object
# Country                  object
# dtype: object

# %% [markdown]
# Check for missing values

# %%
data.isnull().sum()
# Out:
# Order ID                0
# Order Date              0
# Unit Cost               0
# Price                   0
# Order Qty               0
# Cost of Sales           0
# Sales                   0
# Profit                  0
# Channel                 0
# Promotion Name          0
# Product Name            0
# Manufacturer            0
# Product Sub Category    0
# Product Category        0
# Region                  0
# City                    0
# Country                 0
# dtype: int64

# %% [markdown]
# Describe the dataset

# %%
data.describe()
# Out:
#            Order ID     Unit Cost         Price     Order Qty  Cost of Sales  \
# count  15000.000000  15000.000000  15000.000000  15000.000000   15000.000000
# mean   11209.316600    124.425132    296.514697     16.741733    1586.954833
# std     6451.583877    163.569912    345.985232     43.490032    2408.961430
# min        1.000000      0.001576      0.950000      4.000000       0.015756
# 25%     5629.750000     16.847345     59.000000      9.000000     189.677420
# 50%    11238.500000     69.688876    205.000000     10.000000     752.752320
# 75%    16789.500000    164.348636    366.000000     13.000000    2006.030238
# max    22352.000000   1896.133845   2899.990000   1560.000000   42991.137190
#
#               Sales        Profit
# count  15000.000000  15000.000000
# mean    3692.783986   2105.829152
# std     4917.886955   3387.145437
# min        4.750000   -838.426733
# 25%      645.000000    242.198732
# 50%     2301.175750   1012.683637
# 75%     4767.720000   2573.128436
# max    78312.000000  55692.569520

# %% [markdown]
# Find unique values in the 'Region' column

# %%
data['Region'].unique()
# Out:
# array(['Europe', 'Asia', 'North America'], dtype=object)

# %% [markdown]
# Filter data for a specific region (e.g., Europe)

# %%
europe_data = data[data['Region'] == 'Europe']
europe_data
# Out:
#        Order ID Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 0             1     6/3/16   10.297929  198.00          8      82.383431
# 3          1000     2/8/17   31.489398   99.00          4     125.957591
# 4         10000     3/4/19   20.634788   22.99          8     165.078305
# 5         10001    7/28/16   20.156840  169.00         12     241.882079
# 11         1001    4/13/17  163.513993  799.00          8    1308.111940
# ...         ...        ...         ...     ...        ...            ...
# 14974      9955    8/18/18  143.063564  268.00         12    1716.762766
# 14975      9956     8/6/18    0.968351   12.99         24      23.240429
# 14992      9989    6/26/18    9.631663   11.50         16     154.106615
# 14996      9993    2/23/19  173.672641  699.00          9    1563.053767
# 14997      9995    9/13/17  339.125266  411.00         12    4069.503190
#
#            Sales       Profit   Channel                     Promotion Name  \
# 0      1544.4000  1462.016569     Store         European Holiday Promotion
# 3       396.0000   270.042409     Store  European Back-to-Scholl Promotion
# 4       170.1260     5.047695    Online         European Holiday Promotion
# 5      2028.0000  1786.117921     Store          European Spring Promotion
# 11     5912.6000  4604.488060     Store         European Holiday Promotion
# ...          ...          ...       ...                                ...
# 14974  3216.0000  1499.237234     Store          European Spring Promotion
# 14975   309.0321   285.791671    Online          European Spring Promotion
# 14992   174.8000    20.693385  Reseller         European Holiday Promotion
# 14996  6221.1000  4658.046233     Store  European Back-to-Scholl Promotion
# 14997  4932.0000   862.496810    Online          European Spring Promotion
#
#                                             Product Name  \
# 0         A. Datum Point Shoot Digital Camera M500 Black
# 3                                   WWI LCD17 E200 Black
# 4                     Contoso Multi-line phones M30 Grey
# 5                Proseware Ink Jet All in one M300 White
# 11     Litware Home Theater System 7.1 Channel M710 B...
# ...                                                  ...
# 14974  A. Datum Interchangeable lens Non-SLR Digital ...
# 14975  Contoso Dual Handset Cordless Phone System E20...
# 14992      Contoso Desktop Alternative Bundle E200 Black
# 14996                           WWI Laptop15 M0150 Black
# 14997  Fabrikam Budget Movie-Maker 1/3'' 8.5mm E200 B...
#
#                Manufacturer      Product Sub Category  \
# 0      A. Datum Corporation           Digital Cameras
# 3      Wide World Importers                  Monitors
# 4              Contoso, Ltd      Home & Office Phones
# 5           Proseware, Inc.  Printers, Scanners & Fax
# 11            Litware, Inc.       Home Theater System
# ...                     ...                       ...
# 14974  A. Datum Corporation           Digital Cameras
# 14975          Contoso, Ltd      Home & Office Phones
# 14992          Contoso, Ltd     Computers Accessories
# 14996  Wide World Importers                   Laptops
# 14997        Fabrikam, Inc.                Camcorders
#
#               Product Category  Region        City         Country
# 0      Cameras and camcorders   Europe     Baildon  United Kingdom
# 3                    Computers  Europe      Torino           Italy
# 4                  Cell phones  Europe      Berlin         Germany
# 5                    Computers  Europe  Knotty Ash  United Kingdom
# 11                TV and Video  Europe   Bucharest         Romania
# ...                        ...     ...         ...             ...
# 14974  Cameras and camcorders   Europe      Dublin         Ireland
# 14975              Cell phones  Europe      Berlin         Germany
# 14992                Computers  Europe       Paris          France
# 14996                Computers  Europe       Berne     Switzerland
# 14997  Cameras and camcorders   Europe      Berlin         Germany
#
# [3081 rows x 17 columns]

# %% [markdown]
# Group by 'Region' and get the mean of 'Sales'

# %%
region_sales_mean = data.groupby('Region')['Sales'].mean()
region_sales_mean
# Out:
# Region
# Asia             4069.621330
# Europe           3309.268976
# North America    3696.420906
# Name: Sales, dtype: float64

# %% [markdown]
# Sort data by 'Sales' in descending order

# %%
sorted_data = data.sort_values(by='Sales', ascending=False)
sorted_data
# Out:
#        Order ID Order Date    Unit Cost    Price  Order Qty  Cost of Sales  \
# 3509      14712    5/12/18   434.989048  1560.00         52   22619.430480
# 9255       2295     7/5/16   305.051897   980.00         72   21963.736590
# 7835      20561   10/23/17   551.353679  2295.00         30   16540.610380
# 421       10562    5/23/17  1653.505277  2499.00         26   42991.137190
# 6081      18193    8/28/18  1261.817356  2295.00         27   34069.068620
# ...         ...        ...          ...      ...        ...            ...
# 11596      5453    7/12/17     0.753203     0.95          9       6.778830
# 3685      14948     1/3/18     0.354819     0.95          9       3.193370
# 2060      12854    4/25/17     0.477259     0.95          6       2.863554
# 2277      13141    5/22/17     0.758423     0.95          6       4.550540
# 373        1050    3/17/17     0.809138     0.95          5       4.045691
#
#            Sales        Profit  Channel                     Promotion Name  \
# 3509   78312.000  55692.569520  Catalog    North America Holiday Promotion
# 9255   70413.000  48449.263410  Catalog     North America Spring Promotion
# 7835   68850.000  52309.389620   Online                        No Discount
# 421    62475.000  19483.862810   Online    North America Holiday Promotion
# 6081   61161.750  27092.681380   Online     North America Spring Promotion
# ...          ...           ...      ...                                ...
# 11596      8.360      1.581170    Store     North America Spring Promotion
# 3685       8.265      5.071630    Store  European Back-to-Scholl Promotion
# 2060       5.130      2.266446    Store    North America Holiday Promotion
# 2277       5.130      0.579460    Store            Asian Holiday Promotion
# 373        4.750      0.704309   Online                        No Discount
#
#                                             Product Name      Manufacturer  \
# 3509   Fabrikam Independent Filmmaker 1/3'' 8.5mm X20...    Fabrikam, Inc.
# 9255          Fabrikam Trendsetter 2/3'' 17mm X100 Black    Fabrikam, Inc.
# 7835               Proseware Projector 1080p LCD86 White   Proseware, Inc.
# 421                Proseware Projector 1080p DLP86 Black   Proseware, Inc.
# 6081                  Contoso Projector 1080p X980 Black      Contoso, Ltd
# ...                                                  ...               ...
# 11596                        SV USB Data Cable E600 Pink  Southridge Video
# 3685                       SV USB Data Cable E600 Silver  Southridge Video
# 2060                       SV USB Data Cable E600 Silver  Southridge Video
# 2277                         SV USB Data Cable E600 Pink  Southridge Video
# 373                         SV USB Data Cable E600 Black  Southridge Video
#
#         Product Sub Category         Product Category         Region  \
# 3509              Camcorders  Cameras and camcorders   North America
# 9255              Camcorders  Cameras and camcorders   North America
# 7835    Projectors & Screens                Computers  North America
# 421     Projectors & Screens                Computers  North America
# 6081    Projectors & Screens                Computers  North America
# ...                      ...                      ...            ...
# 11596  Computers Accessories                Computers  North America
# 3685   Computers Accessories                Computers         Europe
# 2060   Computers Accessories                Computers  North America
# 2277   Computers Accessories                Computers           Asia
# 373    Computers Accessories                Computers           Asia
#
#                   City        Country
# 3509     North Harford  United States
# 9255     North Harford  United States
# 7835          Bethesda  United States
# 421           Bethesda  United States
# 6081          Bethesda  United States
# ...                ...            ...
# 11596   South Portland  United States
# 3685   Nizhny Novgorod         Russia
# 2060   Fort Lauderdale  United States
# 2277         Singapore      Singapore
# 373            Beijing          China
#
# [15000 rows x 17 columns]

# %% [markdown]
# Create a new column 'Total Cost' (Unit Cost * Order Qty)

# %%
data['Total Cost'] = data['Unit Cost'] * data['Order Qty']
data.head()
# Out:
#    Order ID Order Date  Unit Cost   Price  Order Qty  Cost of Sales     Sales  \
# 0         1     6/3/16  10.297929  198.00          8      82.383431  1544.400
# 1        10    9/10/18  95.053423   99.00         18    1710.961615  1702.800
# 2       100     4/7/17   0.337961  129.00         13       4.393492  1599.600
# 3      1000     2/8/17  31.489398   99.00          4     125.957591   396.000
# 4     10000     3/4/19  20.634788   22.99          8     165.078305   170.126
#
#         Profit   Channel                     Promotion Name  \
# 0  1462.016569     Store         European Holiday Promotion
# 1    -8.161615  Reseller             Asian Spring Promotion
# 2  1595.206508     Store    North America Holiday Promotion
# 3   270.042409     Store  European Back-to-Scholl Promotion
# 4     5.047695    Online         European Holiday Promotion
#
#                                         Product Name          Manufacturer  \
# 0     A. Datum Point Shoot Digital Camera M500 Black  A. Datum Corporation
# 1                   Adventure Works LCD17 E200 Black       Adventure Works
# 2  Proseware Ink Jet Wireless All-In-One Printer ...       Proseware, Inc.
# 3                               WWI LCD17 E200 Black  Wide World Importers
# 4                 Contoso Multi-line phones M30 Grey          Contoso, Ltd
#
#        Product Sub Category         Product Category         Region  \
# 0           Digital Cameras  Cameras and camcorders          Europe
# 1                  Monitors                Computers           Asia
# 2  Printers, Scanners & Fax                Computers  North America
# 3                  Monitors                Computers         Europe
# 4      Home & Office Phones              Cell phones         Europe
#
#                   City         Country   Total Cost
# 0              Baildon  United Kingdom    82.383431
# 1              Beijing           China  1710.961615
# 2  Queen Anne's County   United States     4.393492
# 3               Torino           Italy   125.957591
# 4               Berlin         Germany   165.078305

# %% [markdown]
#  Filter data where 'Profit' is negative

# %%
negative_profit = data[data['Profit'] < 0]
negative_profit
# Out:
#        Order ID Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 1            10    9/10/18   95.053423   99.00         18    1710.961615
# 78        10100     4/8/18  484.690160  480.00          8    3877.521277
# 92        10121    1/25/17   15.251939   15.90          6      91.511633
# 120       10154    5/16/19  273.049724  299.00          8    2184.397793
# 121       10155    2/16/18   12.123082   11.90         12     145.476986
# ...         ...        ...         ...     ...        ...            ...
# 14583      9401    9/20/17  100.519896   99.00          9     904.679068
# 14649      9492     1/1/18  199.137247  199.00         10    1991.372470
# 14887      9830    12/9/16   13.124457   12.99          6      78.746745
# 14906      9856    5/11/17   40.278573   41.99          4     161.114290
# 14985      9973    9/20/16   98.939279  102.00          4     395.757117
#
#           Sales      Profit   Channel                          Promotion Name  \
# 1      1702.800   -8.161615  Reseller                  Asian Spring Promotion
# 78     3648.000 -229.521277     Store              European Holiday Promotion
# 92       89.040   -2.471633  Reseller  North America Back-to-School Promotion
# 120    2152.800  -31.597793     Store              European Holiday Promotion
# 121     142.800   -2.676986     Store  North America Back-to-School Promotion
# ...         ...         ...       ...                                     ...
# 14583   871.200  -33.479068     Store                  Asian Spring Promotion
# 14649  1990.000   -1.372470     Store                             No Discount
# 14887    72.744   -6.002745     Store  North America Back-to-School Promotion
# 14906   134.368  -26.746290     Store              European Holiday Promotion
# 14985   387.600   -8.157117    Online                  Asian Spring Promotion
#
#                                             Product Name  \
# 1                       Adventure Works LCD17 E200 Black
# 78     Contoso Home Theater System 4.1 Channel M1420 ...
# 92      Contoso USB Wave Multi-media Keyboard E280 Black
# 120                       SV Car Video TFT7 M7000 Silver
# 121            Contoso 90W AC/DC Power Adapter E300 Grey
# ...                                                  ...
# 14583                               WWI CRT17 E106 White
# 14649                     SV Car Video AM/FM E1000 Brown
# 14887                     Contoso DVD Movies E100 Yellow
# 14906                 SV PCI Network Adapter E903 Silver
# 14985      SV 80GB USB2.0 Portable Hard Disk E500 Silver
#
#                Manufacturer   Product Sub Category  \
# 1           Adventure Works               Monitors
# 78             Contoso, Ltd    Home Theater System
# 92             Contoso, Ltd  Computers Accessories
# 120        Southridge Video              Car Video
# 121            Contoso, Ltd  Computers Accessories
# ...                     ...                    ...
# 14583  Wide World Importers               Monitors
# 14649      Southridge Video              Car Video
# 14887          Contoso, Ltd              Movie DVD
# 14906      Southridge Video  Computers Accessories
# 14985      Southridge Video  Computers Accessories
#
#                     Product Category         Region       City  \
# 1                          Computers           Asia    Beijing
# 78                      TV and Video         Europe   Toulouse
# 92                         Computers  North America    Seattle
# 120                     TV and Video         Europe   Valletta
# 121                        Computers  North America  Englewood
# ...                              ...            ...        ...
# 14583                      Computers           Asia     Sydney
# 14649                   TV and Video           Asia  Islamabad
# 14887  Music, Movies and Audio Books  North America     Oswego
# 14906                      Computers         Europe  Edinburgh
# 14985                      Computers           Asia    Beijing
#
#               Country   Total Cost
# 1               China  1710.961615
# 78             France  3877.521277
# 92      United States    91.511633
# 120             Malta  2184.397793
# 121     United States   145.476986
# ...               ...          ...
# 14583       Australia   904.679068
# 14649        Pakistan  1991.372470
# 14887   United States    78.746745
# 14906  United Kingdom   161.114290
# 14985           China   395.757117
#
# [213 rows x 18 columns]

# %% [markdown]
# Get the maximum 'Sales' value

# %%
max_sales = data['Sales'].max()
max_sales
# Out:
# np.float64(78312.0)

# %% [markdown]
# Get the row with the maximum 'Sales' value

# %%
max_sales_row = data.loc[data['Sales'].idxmax()]
max_sales_row
# Out:
# Order ID                                                            14712
# Order Date                                                        5/12/18
# Unit Cost                                                      434.989048
# Price                                                              1560.0
# Order Qty                                                              52
# Cost of Sales                                                 22619.43048
# Sales                                                             78312.0
# Profit                                                        55692.56952
# Channel                                                           Catalog
# Promotion Name                            North America Holiday Promotion
# Product Name            Fabrikam Independent Filmmaker 1/3'' 8.5mm X20...
# Manufacturer                                               Fabrikam, Inc.
# Product Sub Category                                           Camcorders
# Product Category                                  Cameras and camcorders
# Region                                                      North America
# City                                                        North Harford
# Country                                                     United States
# Total Cost                                                    22619.43048
# Name: 3509, dtype: object

# %% [markdown]
# Get the minimum 'Profit' value

# %%
min_profit = data['Profit'].min()
min_profit
# Out:
# np.float64(-838.4267326)

# %% [markdown]
#  Get the row with the minimum 'Profit' value

# %%
min_profit_row = data.loc[data['Profit'].idxmin()]
min_profit_row
# Out:
# Order ID                                         16023
# Order Date                                     6/19/17
# Unit Cost                                   507.739171
# Price                                            499.0
# Order Qty                                           16
# Cost of Sales                              8123.826733
# Sales                                           7285.4
# Profit                                     -838.426733
# Channel                                         Online
# Promotion Name              European Holiday Promotion
# Product Name            WWI Projector 480p DLP12 Black
# Manufacturer                      Wide World Importers
# Product Sub Category              Projectors & Screens
# Product Category                             Computers
# Region                                          Europe
# City                                            Berlin
# Country                                        Germany
# Total Cost                                 8123.826733
# Name: 4480, dtype: object

# %% [markdown]
# Calculate the total 'Sales' for each 'Product Category'

# %%
total_sales_category = data.groupby('Product Category')['Sales'].sum()
total_sales_category.apply(int)
# Out:
# Product Category
# Audio                             1029381
# Cameras and camcorders           17048931
# Cell phones                       5841155
# Computers                        21306971
# Music, Movies and Audio Books     1057480
# TV and Video                      9107839
# Name: Sales, dtype: int64

# %% [markdown]
# Plot a bar chart of total 'Sales' by 'Product Category'

# %%
import matplotlib.pyplot as plt

total_sales_category.plot(kind='bar')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product Category')
plt.show()

# %% [markdown]
# Calculate the average 'Unit Cost' for each 'Product Category'

# %%
avg_unit_cost_category = data.groupby('Product Category')['Unit Cost'].mean()
avg_unit_cost_category
# Out:
# Product Category
# Audio                             48.345589
# Cameras and camcorders           158.491294
# Cell phones                       71.225248
# Computers                        129.032176
# Music, Movies and Audio Books     41.165748
# TV and Video                     186.605038
# Name: Unit Cost, dtype: float64

# %% [markdown]
# Find the number of unique 'Product Name'

# %%
unique_products = data['Product Name'].nunique()
unique_products
# Out:
# 1638

# %% [markdown]
# Get the top 5 'Product Name' by 'Sales'

# %%
top_products_by_sales = data.groupby('Product Name')['Sales'].sum().nlargest()
top_products_by_sales
# Out:
# Product Name
# Contoso Projector 1080p X980 Black        445115.25
# Proseware Projector 1080p LCD86 White     417575.25
# Contoso Projector 1080p X980 White        399903.75
# Proseware Projector 1080p LCD86 Black     360567.45
# Proseware Projector 1080p DLP86 Silver    358806.42
# Name: Sales, dtype: float64

# %% [markdown]
# Get the number of orders for each 'Channel'

# %%
orders_per_channel = data['Channel'].value_counts()
print(orders_per_channel)
# Out:
# Channel
# Store       9981
# Online      2351
# Reseller    1784
# Catalog      884
# Name: count, dtype: int64

# %% [markdown]
# Calculate the total 'Profit' for each 'Country'

# %%
total_profit_country = data.groupby('Country')['Profit'].sum()
total_profit_country.apply(int)
# Out:
# Country
# Armenia              111970
# Australia            344234
# Bhutan                88175
# Canada               668871
# China               4392369
# Denmark               45194
# France              1401589
# Germany             2473281
# Greece                42992
# India                357657
# Iran                 192561
# Ireland               61752
# Italy                170682
# Japan                555052
# Kyrgyzstan            71146
# Malta                 63406
# Pakistan             169432
# Poland                45921
# Portugal              78672
# Romania               66761
# Russia               262063
# Singapore             41832
# Slovenia              43419
# South Korea          150636
# Spain                103229
# Sweden                50611
# Switzerland           66024
# Syria                179031
# Taiwan               109273
# Thailand             151820
# Turkmenistan         229499
# United Kingdom       729551
# United States      17999958
# the Netherlands       68759
# Name: Profit, dtype: int64

# %% [markdown]
# Plot a pie chart of total 'Sales' by 'Region'

# %%
total_sales_region = data.groupby('Region')['Sales'].sum()
total_sales_region.plot(kind='pie', autopct='%1.1f%%')
plt.title('Total Sales by Region')
# Out:
# Text(0.5, 1.0, 'Total Sales by Region')

# %% [markdown]
# Create a new column 'Profit Margin' (Profit / Sales)

# %%
data['Profit Margin'] = data['Profit'] / data['Sales']
data['Profit Margin']
# Out:
# 0        0.946657
# 1       -0.004793
# 2        0.997253
# 3        0.681925
# 4        0.029670
#            ...
# 14995    0.006205
# 14996    0.748750
# 14997    0.174878
# 14998    0.613486
# 14999    0.449189
# Name: Profit Margin, Length: 15000, dtype: float64

# %% [markdown]
# Find the top 10 orders by 'Profit Margin'

# %%
top_orders_by_profit_margin = data.sort_values(by='Profit Margin', ascending=False).head(10)
top_orders_by_profit_margin
# Out:
#        Order ID Order Date  Unit Cost   Price  Order Qty  Cost of Sales  \
# 8698       2166     9/9/16   0.008362  209.00          9       0.075259
# 12256      6325   11/24/17   0.001576   12.99         10       0.015756
# 6821      19158    10/7/16   0.164012  429.00         10       1.640117
# 4137      15561     1/8/17   0.196739  499.90         27       5.311960
# 5716      17687    6/17/17   0.004508   11.90         13       0.058605
# 11329      5106    7/12/16   0.008311   16.99          4       0.033243
# 10400      3873    2/26/18   0.203765  369.00         54      11.003315
# 12836      7073     7/9/18   0.079045  109.99         18       1.422804
# 3397      14574     7/3/17   0.016954   23.00         12       0.203452
# 5626      17569   10/28/17   0.155981  208.00         10       1.559812
#
#             Sales        Profit   Channel                     Promotion Name  \
# 8698    1797.4000   1797.324741     Store             Asian Spring Promotion
# 12256    129.9000    129.884244     Store                        No Discount
# 6821    4290.0000   4288.359883     Store                        No Discount
# 4137   13397.3200  13392.008040     Store  European Back-to-Scholl Promotion
# 5716     145.1800    145.121395     Store         European Holiday Promotion
# 11329     64.5620     64.528757     Store             Asian Spring Promotion
# 10400  19557.0000  19545.996690    Online  European Back-to-Scholl Promotion
# 12836   1974.3205   1972.897696  Reseller     North America Spring Promotion
# 3397     274.3900    274.186548    Online          European Spring Promotion
# 5626    2080.0000   2078.440188     Store                        No Discount
#
#                                             Product Name       Manufacturer  \
# 8698              Proseware High Speed Laser M2000 Black    Proseware, Inc.
# 12256                  Contoso 512MB MP3 Player E51 Blue       Contoso, Ltd
# 6821   Contoso Home Theater System 5.1 Channel M1500 ...       Contoso, Ltd
# 4137         Adventure Works Desktop PC1.80 ED182 Silver    Adventure Works
# 5716   Contoso Cables To Go USB 2.0 Hard Drive Enclos...       Contoso, Ltd
# 11329  Contoso 3 Handset Cordless Phone System  E30 B...       Contoso, Ltd
# 10400         Adventure Works Desktop PC1.80 ED180 Brown    Adventure Works
# 12836           SV DVD 7-Inch Player Portable E200 White   Southridge Video
# 3397   Contoso Lifestyles Series - Big Button Cordles...       Contoso, Ltd
# 5626     The Phone Company Smart phones 160x160 M26 Pink  The Phone Company
#
#            Product Sub Category               Product Category         Region  \
# 8698   Printers, Scanners & Fax                      Computers           Asia
# 12256                   MP4&MP3                          Audio         Europe
# 6821        Home Theater System                   TV and Video  North America
# 4137                   Desktops                      Computers         Europe
# 5716      Computers Accessories                      Computers         Europe
# 11329      Home & Office Phones                    Cell phones           Asia
# 10400                  Desktops                      Computers         Europe
# 12836                 Movie DVD  Music, Movies and Audio Books  North America
# 3397       Home & Office Phones                    Cell phones         Europe
# 5626       Smart phones & PDAs                     Cell phones         Europe
#
#             City          Country  Total Cost  Profit Margin
# 8698      Sydney        Australia    0.075259       0.999958
# 12256       Roma            Italy    0.015756       0.999879
# 6821    Appleton    United States    1.640117       0.999618
# 4137      Madrid            Spain    5.311960       0.999604
# 5716      Moscow           Russia    0.058605       0.999596
# 11329    Kolkata            India    0.033243       0.999485
# 10400     Berlin          Germany   11.003315       0.999437
# 12836    Seattle    United States    1.422804       0.999279
# 3397      Berlin          Germany    0.203452       0.999259
# 5626   Amsterdam  the Netherlands    1.559812       0.999250

# %% [markdown]
# Group by 'Country' and get the count of orders

# %%
orders_per_country = data.groupby('Country')['Order ID'].count()
orders_per_country
# Out:
# Country
# Armenia              44
# Australia           149
# Bhutan               48
# Canada              359
# China              1673
# Denmark              42
# France              781
# Germany            1118
# Greece               25
# India               152
# Iran                 89
# Ireland              37
# Italy               111
# Japan               298
# Kyrgyzstan           46
# Malta                41
# Pakistan             93
# Poland               37
# Portugal             38
# Romania              39
# Russia              166
# Singapore            49
# Slovenia             34
# South Korea          72
# Spain                32
# Sweden               30
# Switzerland          35
# Syria                86
# Taiwan               50
# Thailand             82
# Turkmenistan        119
# United Kingdom      477
# United States      8510
# the Netherlands      38
# Name: Order ID, dtype: int64

# %% [markdown]
# Calculate the average 'Price' for each 'Product Sub Category'

# %%
avg_price_sub_category = data.groupby('Product Sub Category')['Price'].mean()
avg_price_sub_category
# Out:
# Product Sub Category
# Bluetooth Headphones                 76.598824
# Camcorders                          714.667680
# Cameras & Camcorders Accessories     50.385287
# Car Video                           365.406122
# Cell phones Accessories              13.321057
# Computers Accessories                36.518691
# Desktops                            374.338228
# Digital Cameras                     208.413043
# Digital SLR Cameras                 447.480075
# Home & Office Phones                 29.450634
# Home Theater System                 463.749764
# Laptops                             655.361515
# MP4&MP3                             121.638182
# Monitors                            240.498457
# Movie DVD                           105.125168
# Printers, Scanners & Fax            160.146241
# Projectors & Screens                691.781465
# Recording Pen                       191.400847
# Smart phones & PDAs                 279.704094
# Televisions                         501.288625
# Touch Screen Phones                 282.080501
# VCD & DVD                            96.882723
# Name: Price, dtype: float64

# %% [markdown]
#  Filter data for a specific manufacturer (e.g., Contoso, Ltd)

# %%
contoso_data = data[data['Manufacturer'] == 'Contoso, Ltd']
contoso_data
# Out:
#        Order ID Order Date  Unit Cost  Price  Order Qty  Cost of Sales  \
# 4         10000     3/4/19  20.634788  22.99          8     165.078305
# 9         10008    3/11/18   1.210748  24.99         10      12.107477
# 12        10011    9/15/17  27.514412  46.99          9     247.629712
# 23        10028    8/20/17  22.483728  36.99         12     269.804740
# 27        10035   10/20/16   5.647438  14.52          5      28.237188
# ...         ...        ...        ...    ...        ...            ...
# 14987      9978   12/24/17  18.501770  22.99         24     444.042482
# 14989      9984   11/20/16  31.018342  49.99         10     310.183424
# 14992      9989    6/26/18   9.631663  11.50         16     154.106615
# 14994      9990    9/19/16  10.814061  23.90         10     108.140606
# 14995      9991    10/7/16  13.416234  13.50          5      67.081169
#
#           Sales      Profit   Channel                          Promotion Name  \
# 4      170.1260    5.047695    Online              European Holiday Promotion
# 9      249.9000  237.792523    Online                             No Discount
# 12     385.3180  137.688288     Store                  Asian Spring Promotion
# 23     438.7014  168.896660     Store               European Spring Promotion
# 27      72.6000   44.362812     Store                             No Discount
# ...         ...         ...       ...                                     ...
# 14987  540.2650   96.222518  Reseller  North America Back-to-School Promotion
# 14989  499.9000  189.716577     Store                             No Discount
# 14992  174.8000   20.693385  Reseller              European Holiday Promotion
# 14994  239.0000  130.859394     Store                             No Discount
# 14995   67.5000    0.418831   Catalog                             No Discount
#
#                                             Product Name  Manufacturer  \
# 4                     Contoso Multi-line phones M30 Grey  Contoso, Ltd
# 9           Contoso Mini Battery Charger Kit E320 Silver  Contoso, Ltd
# 12                 Contoso In front of Centrex L15 Black  Contoso, Ltd
# 23           Contoso Multi-Use Terminal Cable E308 Black  Contoso, Ltd
# 27                      Contoso 1G MP3 Player E100 White  Contoso, Ltd
# ...                                                  ...           ...
# 14987  Contoso Waterproof Accessory Handset and Charg...  Contoso, Ltd
# 14989                   Contoso Behind Centrex X15 White  Contoso, Ltd
# 14992      Contoso Desktop Alternative Bundle E200 Black  Contoso, Ltd
# 14994     Contoso Digital camera accessory kit M200 Grey  Contoso, Ltd
# 14995        Contoso Education Supplies Bundle E200 Grey  Contoso, Ltd
#
#                    Product Sub Category         Product Category  \
# 4                  Home & Office Phones              Cell phones
# 9      Cameras & Camcorders Accessories  Cameras and camcorders
# 12                 Home & Office Phones              Cell phones
# 23     Cameras & Camcorders Accessories  Cameras and camcorders
# 27                              MP4&MP3                    Audio
# ...                                 ...                      ...
# 14987              Home & Office Phones              Cell phones
# 14989              Home & Office Phones              Cell phones
# 14992             Computers Accessories                Computers
# 14994             Computers Accessories                Computers
# 14995             Computers Accessories                Computers
#
#               Region                 City          Country  Total Cost  \
# 4             Europe               Berlin          Germany  165.078305
# 9               Asia              Beijing            China   12.107477
# 12              Asia               Tehran             Iran  247.629712
# 23            Europe            Amsterdam  the Netherlands  269.804740
# 27     North America  Queen Anne's County    United States   28.237188
# ...              ...                  ...              ...         ...
# 14987  North America              Seattle    United States  444.042482
# 14989  North America             Falmouth    United States  310.183424
# 14992         Europe                Paris           France  154.106615
# 14994  North America             Beaumont    United States  108.140606
# 14995  North America        North Harford    United States   67.081169
#
#        Profit Margin
# 4           0.029670
# 9           0.951551
# 12          0.357337
# 23          0.384992
# 27          0.611058
# ...              ...
# 14987       0.178102
# 14989       0.379509
# 14992       0.118383
# 14994       0.547529
# 14995       0.006205
#
# [4891 rows x 19 columns]

# %% [markdown]
# Calculate the total 'Sales' and 'Profit' for each 'Manufacturer'

# %%
sales_profit_manufacturer = data.groupby('Manufacturer')[['Sales', 'Profit']].sum()
sales_profit_manufacturer.applymap(int)
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_53242/3095061261.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sales_profit_manufacturer.applymap(int)
#                          Sales   Profit
# Manufacturer
# A. Datum Corporation   4404982  2608508
# Adventure Works        7467703  4158548
# Contoso, Ltd           9996750  5670159
# Fabrikam, Inc.        12054281  7158976
# Litware, Inc.          2134836  1120286
# Northwind Traders       136571    73528
# Proseware, Inc.        5996829  3513124
# Southridge Video       3112730  1610013
# The Phone Company      4386164  2476148
# Wide World Importers   5700910  3198143

# %% [markdown]
# Plot a line chart of 'Sales' over time

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
sales_over_time = data.groupby('Order Date')['Sales'].sum()
sales_over_time.plot(kind='line')
plt.ylabel('Total Sales')
plt.title('Sales Over Time')
plt.show()
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_53242/2509996673.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Order Date'] = pd.to_datetime(data['Order Date'])

# %% [markdown]
# Calculate the total 'Sales' for each 'City'

# %%
total_sales_city = data.groupby('City')['Sales'].sum()
total_sales_city
# Out:
# City
# Albany        115139.8810
# Alexandria    114897.9605
# Amsterdam     107746.5264
# Anchorage      62895.3420
# Annapolis     134862.2775
#                  ...
# Worcester     183950.3910
# Yakima        100843.5140
# Yerevan       172934.6530
# Yokohama      150851.1085
# York           47645.5707
# Name: Sales, Length: 263, dtype: float64

# %% [markdown]
# Plot a bar chart of total 'Sales' by 'City'

# %%
top_cities_by_sales = total_sales_city.nlargest(10)
top_cities_by_sales.plot(kind='bar')
plt.ylabel('Total Sales')
plt.title('Top 10 Cities by Total Sales')
plt.show()

# %% [markdown]
#  Calculate the average 'Order Qty' for each 'Promotion Name'

# %%
avg_order_qty_promotion = data.groupby('Promotion Name')['Order Qty'].mean()
avg_order_qty_promotion
# Out:
# Promotion Name
# Asian Holiday Promotion                   22.672000
# Asian Spring Promotion                    14.738255
# Asian Summer Promotion                    19.614458
# European Back-to-Scholl Promotion         14.159615
# European Holiday Promotion                12.027317
# European Spring Promotion                 18.314840
# No Discount                               15.375840
# North America Back-to-School Promotion    19.310294
# North America Holiday Promotion           21.478445
# North America Spring Promotion            14.733526
# Name: Order Qty, dtype: float64

# %% [markdown]
# Get the number of orders for each 'Product Sub Category'

# %%
orders_per_sub_category = data['Product Sub Category'].value_counts()
orders_per_sub_category
# Out:
# Product Sub Category
# Computers Accessories               1642
# Digital SLR Cameras                 1069
# Digital Cameras                     1012
# Camcorders                           987
# Printers, Scanners & Fax             971
# Home & Office Phones                 930
# Projectors & Screens                 874
# Smart phones & PDAs                  855
# Home Theater System                  848
# Movie DVD                            832
# Laptops                              812
# Monitors                             648
# Touch Screen Phones                  559
# Cameras & Camcorders Accessories     522
# Car Video                            490
# Desktops                             412
# Televisions                          349
# MP4&MP3                              308
# Bluetooth Headphones                 306
# Cell phones Accessories              265
# VCD & DVD                            191
# Recording Pen                        118
# Name: count, dtype: int64

# %% [markdown]
# Calculate the total 'Cost of Sales' for each 'Channel'

# %%
total_cost_channel = data.groupby('Channel')['Cost of Sales'].sum()
total_cost_channel.apply(int)
# Out:
# Channel
# Catalog      2104396
# Online       4970490
# Reseller     3058067
# Store       13671368
# Name: Cost of Sales, dtype: int64

# %% [markdown]
# Calculate the total 'Profit' for each 'Region'

# %%
total_profit_region = data.groupby('Region')['Profit'].sum()
total_profit_region
# Out:
# Region
# Asia             7.144694e+06
# Europe           5.773913e+06
# North America    1.866883e+07
# Name: Profit, dtype: float64

# %% [markdown]
# Plot a bar chart of total 'Profit' by 'Region'

# %%
total_profit_region.plot(kind='bar')
plt.ylabel('Total Profit')
plt.title('Total Profit by Region')
plt.show()

# %% [markdown]
# Find the top 5 'Promotion Name' by 'Sales'

# %%
top_promotions_by_sales = data.groupby('Promotion Name')['Sales'].sum().nlargest(5)
top_promotions_by_sales
# Out:
# Promotion Name
# No Discount                               1.832936e+07
# North America Back-to-School Promotion    8.455761e+06
# North America Holiday Promotion           6.451629e+06
# North America Spring Promotion            6.374333e+06
# Asian Holiday Promotion                   3.615194e+06
# Name: Sales, dtype: float64

# %% [markdown]
# Calculate the average 'Price' for each 'Manufacturer'

# %%
avg_price_manufacturer = data.groupby('Manufacturer')['Price'].mean()
avg_price_manufacturer
# Out:
# Manufacturer
# A. Datum Corporation    267.940387
# Adventure Works         483.549893
# Contoso, Ltd            155.871621
# Fabrikam, Inc.          627.292555
# Litware, Inc.           538.237931
# Northwind Traders        51.933786
# Proseware, Inc.         315.622910
# Southridge Video        171.705312
# The Phone Company       281.374429
# Wide World Importers    429.813010
# Name: Price, dtype: float64

# %% [markdown]
# Filter data for a specific product category (e.g., Computers)

# %%
computers_data = data[data['Product Category'] == 'Computers']
computers_data
# Out:
#        Order ID Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 1            10 2018-09-10   95.053423   99.00         18    1710.961615
# 2           100 2017-04-07    0.337961  129.00         13       4.393492
# 3          1000 2017-02-08   31.489398   99.00          4     125.957591
# 5         10001 2016-07-28   20.156840  169.00         12     241.882079
# 6         10004 2017-11-23  117.255981  219.95         20    2345.119622
# ...         ...        ...         ...     ...        ...            ...
# 14991      9988 2017-08-15   64.519155  279.00         27    1742.017175
# 14992      9989 2018-06-26    9.631663   11.50         16     154.106615
# 14994      9990 2016-09-19   10.814061   23.90         10     108.140606
# 14995      9991 2016-10-07   13.416234   13.50          5      67.081169
# 14996      9993 2019-02-23  173.672641  699.00          9    1563.053767
#
#          Sales       Profit   Channel                     Promotion Name  \
# 1      1702.80    -8.161615  Reseller             Asian Spring Promotion
# 2      1599.60  1595.206508     Store    North America Holiday Promotion
# 3       396.00   270.042409     Store  European Back-to-Scholl Promotion
# 5      2028.00  1786.117921     Store          European Spring Promotion
# 6      4399.00  2053.880378   Catalog                        No Discount
# ...        ...          ...       ...                                ...
# 14991  7435.35  5693.332825  Reseller     North America Spring Promotion
# 14992   174.80    20.693385  Reseller         European Holiday Promotion
# 14994   239.00   130.859394     Store                        No Discount
# 14995    67.50     0.418831   Catalog                        No Discount
# 14996  6221.10  4658.046233     Store  European Back-to-Scholl Promotion
#
#                                             Product Name  \
# 1                       Adventure Works LCD17 E200 Black
# 2      Proseware Ink Jet Wireless All-In-One Printer ...
# 3                                   WWI LCD17 E200 Black
# 5                Proseware Ink Jet All in one M300 White
# 6                         WWI Desktop PC1.60 E1600 Black
# ...                                                  ...
# 14991                        Proseware LCD20W M230 White
# 14992      Contoso Desktop Alternative Bundle E200 Black
# 14994     Contoso Digital camera accessory kit M200 Grey
# 14995        Contoso Education Supplies Bundle E200 Grey
# 14996                           WWI Laptop15 M0150 Black
#
#                Manufacturer      Product Sub Category Product Category  \
# 1           Adventure Works                  Monitors        Computers
# 2           Proseware, Inc.  Printers, Scanners & Fax        Computers
# 3      Wide World Importers                  Monitors        Computers
# 5           Proseware, Inc.  Printers, Scanners & Fax        Computers
# 6      Wide World Importers                  Desktops        Computers
# ...                     ...                       ...              ...
# 14991       Proseware, Inc.                  Monitors        Computers
# 14992          Contoso, Ltd     Computers Accessories        Computers
# 14994          Contoso, Ltd     Computers Accessories        Computers
# 14995          Contoso, Ltd     Computers Accessories        Computers
# 14996  Wide World Importers                   Laptops        Computers
#
#               Region                 City         Country   Total Cost  \
# 1               Asia              Beijing           China  1710.961615
# 2      North America  Queen Anne's County   United States     4.393492
# 3             Europe               Torino           Italy   125.957591
# 5             Europe           Knotty Ash  United Kingdom   241.882079
# 6      North America        North Harford   United States  2345.119622
# ...              ...                  ...             ...          ...
# 14991  North America              Seattle   United States  1742.017174
# 14992         Europe                Paris          France   154.106615
# 14994  North America             Beaumont   United States   108.140606
# 14995  North America        North Harford   United States    67.081169
# 14996         Europe                Berne     Switzerland  1563.053767
#
#        Profit Margin
# 1          -0.004793
# 2           0.997253
# 3           0.681925
# 5           0.880729
# 6           0.466897
# ...              ...
# 14991       0.765711
# 14992       0.118383
# 14994       0.547529
# 14995       0.006205
# 14996       0.748750
#
# [5359 rows x 19 columns]

# %% [markdown]
# Calculate the total 'Sales' for each 'Promotion Name'

# %%
total_sales_promotion = data.groupby('Promotion Name')['Sales'].sum()
total_sales_promotion
# Out:
# Promotion Name
# Asian Holiday Promotion                   3.615194e+06
# Asian Spring Promotion                    2.396001e+06
# Asian Summer Promotion                    2.278683e+06
# European Back-to-Scholl Promotion         1.668024e+06
# European Holiday Promotion                3.083456e+06
# European Spring Promotion                 2.739319e+06
# No Discount                               1.832936e+07
# North America Back-to-School Promotion    8.455761e+06
# North America Holiday Promotion           6.451629e+06
# North America Spring Promotion            6.374333e+06
# Name: Sales, dtype: float64

# %% [markdown]
# Plot a bar chart of total 'Sales' by 'Promotion Name'

# %%
top_promotions_by_sales.plot(kind='bar')
plt.ylabel('Total Sales')
plt.title('Top 5 Promotions by Total Sales')
plt.show()

# %% [markdown]
# Calculate the total 'Sales' and 'Profit' for each 'Product Sub Category'

# %%
sales_profit_sub_category = data.groupby('Product Sub Category')[['Sales', 'Profit']].sum()
print(sales_profit_sub_category)
# Out:
#                                          Sales        Profit
# Product Sub Category
# Bluetooth Headphones              2.776604e+05  1.527955e+05
# Camcorders                        8.456121e+06  4.972853e+06
# Cameras & Camcorders Accessories  3.218289e+05  1.706889e+05
# Car Video                         2.093144e+06  1.065879e+06
# Cell phones Accessories           8.259484e+05  4.683719e+05
# Computers Accessories             7.099274e+05  3.599366e+05
# Desktops                          3.491787e+06  1.762033e+06
# Digital Cameras                   2.539792e+06  1.455482e+06
# Digital SLR Cameras               5.731190e+06  3.503778e+06
# Home & Office Phones              3.196451e+05  1.767174e+05
# Home Theater System               4.737968e+06  2.470355e+06
# Laptops                           6.403174e+06  3.763974e+06
# MP4&MP3                           4.599606e+05  2.672530e+05
# Monitors                          1.868936e+06  1.090990e+06
# Movie DVD                         1.057480e+06  6.352851e+05
# Printers, Scanners & Fax          1.796972e+06  1.040435e+06
# Projectors & Screens              7.036175e+06  4.145050e+06
# Recording Pen                     2.917603e+05  1.572218e+05
# Smart phones & PDAs               2.822295e+06  1.585115e+06
# Televisions                       2.064342e+06  1.179151e+06
# Touch Screen Phones               1.873268e+06  1.055722e+06
# VCD & DVD                         2.123863e+05  1.083490e+05

# %% [markdown]
# Get the average 'Profit Margin' for each 'Region'

# %%
avg_profit_margin_region = data.groupby('Region')['Profit Margin'].mean()
avg_profit_margin_region
# Out:
# Region
# Asia             0.539792
# Europe           0.535643
# North America    0.540168
# Name: Profit Margin, dtype: float64

# %% [markdown]
# Filter data for orders with 'Order Qty' greater than 10

# %%
large_orders = data[data['Order Qty'] > 10]
large_orders
# Out:
#        Order ID Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 1            10 2018-09-10   95.053423   99.00         18    1710.961615
# 2           100 2017-04-07    0.337961  129.00         13       4.393492
# 5         10001 2016-07-28   20.156840  169.00         12     241.882079
# 6         10004 2017-11-23  117.255981  219.95         20    2345.119622
# 7         10005 2017-12-17  144.156217  299.00         36    5189.623824
# ...         ...        ...         ...     ...        ...            ...
# 14991      9988 2017-08-15   64.519155  279.00         27    1742.017175
# 14992      9989 2018-06-26    9.631663   11.50         16     154.106615
# 14993       999 2016-12-14   90.774859  179.99         24    2178.596613
# 14997      9995 2017-09-13  339.125266  411.00         12    4069.503190
# 14998      9997 2018-01-31   72.059072  188.00         12     864.708865
#
#           Sales       Profit   Channel  \
# 1       1702.80    -8.161615  Reseller
# 2       1599.60  1595.206508     Store
# 5       2028.00  1786.117921     Store
# 6       4399.00  2053.880378   Catalog
# 7      10614.50  5424.876176    Online
# ...         ...          ...       ...
# 14991   7435.35  5693.332825  Reseller
# 14992    174.80    20.693385  Reseller
# 14993   4319.76  2141.163387    Online
# 14997   4932.00   862.496810    Online
# 14998   2237.20  1372.491135     Store
#
#                                Promotion Name  \
# 1                      Asian Spring Promotion
# 2             North America Holiday Promotion
# 5                   European Spring Promotion
# 6                                 No Discount
# 7      North America Back-to-School Promotion
# ...                                       ...
# 14991          North America Spring Promotion
# 14992              European Holiday Promotion
# 14993                             No Discount
# 14997               European Spring Promotion
# 14998  North America Back-to-School Promotion
#
#                                             Product Name  \
# 1                       Adventure Works LCD17 E200 Black
# 2      Proseware Ink Jet Wireless All-In-One Printer ...
# 5                Proseware Ink Jet All in one M300 White
# 6                         WWI Desktop PC1.60 E1600 Black
# 7      The Phone Company Touch Screen Phones SAW/Buil...
# ...                                                  ...
# 14991                        Proseware LCD20W M230 White
# 14992      Contoso Desktop Alternative Bundle E200 Black
# 14993          SV DVD 12-Inch Player Portable M400 Black
# 14997  Fabrikam Budget Movie-Maker 1/3'' 8.5mm E200 B...
# 14998       A. Datum All in One Digital Camera M200 Pink
#
#                Manufacturer      Product Sub Category  \
# 1           Adventure Works                  Monitors
# 2           Proseware, Inc.  Printers, Scanners & Fax
# 5           Proseware, Inc.  Printers, Scanners & Fax
# 6      Wide World Importers                  Desktops
# 7         The Phone Company      Touch Screen Phones
# ...                     ...                       ...
# 14991       Proseware, Inc.                  Monitors
# 14992          Contoso, Ltd     Computers Accessories
# 14993      Southridge Video                 Movie DVD
# 14997        Fabrikam, Inc.                Camcorders
# 14998  A. Datum Corporation           Digital Cameras
#
#                     Product Category         Region                 City  \
# 1                          Computers           Asia              Beijing
# 2                          Computers  North America  Queen Anne's County
# 5                          Computers         Europe           Knotty Ash
# 6                          Computers  North America        North Harford
# 7                        Cell phones  North America             Bethesda
# ...                              ...            ...                  ...
# 14991                      Computers  North America              Seattle
# 14992                      Computers         Europe                Paris
# 14993  Music, Movies and Audio Books           Asia              Beijing
# 14997        Cameras and camcorders          Europe               Berlin
# 14998        Cameras and camcorders   North America               Oregon
#
#               Country   Total Cost  Profit Margin
# 1               China  1710.961615      -0.004793
# 2       United States     4.393492       0.997253
# 5      United Kingdom   241.882079       0.880729
# 6       United States  2345.119622       0.466897
# 7       United States  5189.623823       0.511082
# ...               ...          ...            ...
# 14991   United States  1742.017174       0.765711
# 14992          France   154.106615       0.118383
# 14993           China  2178.596613       0.495667
# 14997         Germany  4069.503190       0.174878
# 14998   United States   864.708865       0.613486
#
# [6747 rows x 19 columns]

# %% [markdown]
# Calculate the total 'Sales' for each 'City' in Europe

# %%
europe_sales_city = europe_data.groupby('City')['Sales'].sum()
europe_sales_city.apply(int)
# Out:
# City
# Amsterdam             107746
# Athens                 68527
# Baildon                77925
# Bamberg               138773
# Baumholder            153510
# Berlin               3255278
# Berne                  99362
# Bucharest             102278
# Cambridge              71053
# Carlisle               98403
# Cheshire              104222
# Copenhagen             79145
# Dublin                 92123
# Dusseldorf             71706
# Edinburgh             105007
# Firenze                84089
# Giebelstadt            68414
# Glasgow                86150
# Hofheim am Taunus     123001
# Knotty Ash             91940
# Koln                  196646
# Lancashire             83417
# Landstuhl              80082
# Leeds                  98608
# Lisbon                126381
# Liverpool             147914
# Ljubljana              79881
# London                 47725
# Lyon                   60124
# Madrid                143433
# Manchester             76268
# Marseille              11091
# Milan                 100309
# Moscow                239914
# Munich                114792
# Nantes                112748
# Nice                   85802
# Nizhny Novgorod       114174
# Paris                2156623
# Ramstein              112750
# Roma                   44251
# Saint Petersburg       80151
# Stockholm              78106
# Stockport             111326
# Strasbourg             94719
# Torino                 87692
# Toulouse              107290
# Valletta              112295
# Venezia                  538
# Warsaw                 87829
# West Yorkshire         76659
# York                   47645
# Name: Sales, dtype: int64

# %% [markdown]
# Find the top 5 'City' by 'Sales' in Europe

# %%
europe_sales_city
# Out:
# City
# Amsterdam            1.077465e+05
# Athens               6.852796e+04
# Baildon              7.792522e+04
# Bamberg              1.387736e+05
# Baumholder           1.535104e+05
# Berlin               3.255279e+06
# Berne                9.936224e+04
# Bucharest            1.022789e+05
# Cambridge            7.105357e+04
# Carlisle             9.840357e+04
# Cheshire             1.042225e+05
# Copenhagen           7.914523e+04
# Dublin               9.212368e+04
# Dusseldorf           7.170686e+04
# Edinburgh            1.050072e+05
# Firenze              8.408981e+04
# Giebelstadt          6.841419e+04
# Glasgow              8.615048e+04
# Hofheim am Taunus    1.230013e+05
# Knotty Ash           9.194005e+04
# Koln                 1.966461e+05
# Lancashire           8.341707e+04
# Landstuhl            8.008251e+04
# Leeds                9.860869e+04
# Lisbon               1.263816e+05
# Liverpool            1.479148e+05
# Ljubljana            7.988141e+04
# London               4.772505e+04
# Lyon                 6.012471e+04
# Madrid               1.434332e+05
# Manchester           7.626835e+04
# Marseille            1.109159e+04
# Milan                1.003092e+05
# Moscow               2.399146e+05
# Munich               1.147922e+05
# Nantes               1.127484e+05
# Nice                 8.580226e+04
# Nizhny Novgorod      1.141745e+05
# Paris                2.156624e+06
# Ramstein             1.127504e+05
# Roma                 4.425175e+04
# Saint Petersburg     8.015114e+04
# Stockholm            7.810665e+04
# Stockport            1.113260e+05
# Strasbourg           9.471933e+04
# Torino               8.769232e+04
# Toulouse             1.072904e+05
# Valletta             1.122952e+05
# Venezia              5.380000e+02
# Warsaw               8.782953e+04
# West Yorkshire       7.665909e+04
# York                 4.764557e+04
# Name: Sales, dtype: float64

# %%
top_cities_by_sales_europe = europe_sales_city.nlargest(5)
top_cities_by_sales_europe
# Out:
# City
# Berlin        3.255279e+06
# Paris         2.156624e+06
# Moscow        2.399146e+05
# Koln          1.966461e+05
# Baumholder    1.535104e+05
# Name: Sales, dtype: float64
